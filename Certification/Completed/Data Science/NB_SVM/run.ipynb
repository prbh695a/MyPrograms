# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
df=pd.read_csv("/Users/prateekb/Downloads/MyPrograms/Certification/WIP/Machine Learning/NB_SVM/run_or_walk.csv")
print(df.columns)
# Out:
# Index(['date', 'time', 'username', 'wrist', 'activity', 'acceleration_x',
#        'acceleration_y', 'acceleration_z', 'gyro_x', 'gyro_y', 'gyro_z'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['date', 'time', 'username', 'wrist', 'activity', 'acceleration_x',
#        'acceleration_y', 'acceleration_z', 'gyro_x', 'gyro_y', 'gyro_z'],
#       dtype='object')

# %%
X=df.iloc[:,5:11]
Y=df['activity']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
nb=GaussianNB()
nb.fit(X_train,Y_train)
Y_pred=nb.predict(X_test)
Y_pred_train=nb.predict(X_train)

print("The test classification report is: \n",classification_report(Y_pred,Y_test))
from sklearn.metrics import accuracy_score
print("The test accuracy score is: ",accuracy_score(Y_pred,Y_test))
# Out:
# The test classification report is:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      9487
#            1       0.93      0.99      0.96      8231
#
#     accuracy                           0.96     17718
#    macro avg       0.96      0.96      0.96     17718
# weighted avg       0.96      0.96      0.96     17718
#
# The test accuracy score is:  0.958008804605486

# %%
corr=X.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()

X=df.iloc[:,5:11]
Y=df['activity']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

nb=GaussianNB()
nb.fit(X_train,Y_train)
Y_pred=nb.predict(X_test)
Y_pred_train=nb.predict(X_train)

print("The test classification report is: \n",classification_report(Y_pred,Y_test))
from sklearn.metrics import accuracy_score
print("The test accuracy score is: ",accuracy_score(Y_pred,Y_test))
# Out:
# The test classification report is:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      9487
#            1       0.93      0.99      0.96      8231
#
#     accuracy                           0.96     17718
#    macro avg       0.96      0.96      0.96     17718
# weighted avg       0.96      0.96      0.96     17718
#
# The test accuracy score is:  0.958008804605486

# %%
X=df.iloc[:,5:8]
corr=X.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()


Y=df['activity']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

nb=GaussianNB()
nb.fit(X_train,Y_train)
Y_pred=nb.predict(X_test)
Y_pred_train=nb.predict(X_train)

print("The test classification report is: \n",classification_report(Y_pred,Y_test))
from sklearn.metrics import accuracy_score
print("The test accuracy score is: ",accuracy_score(Y_pred,Y_test))
# Out:
# The test classification report is:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      9533
#            1       0.92      0.99      0.96      8185
#
#     accuracy                           0.96     17718
#    macro avg       0.96      0.96      0.96     17718
# weighted avg       0.96      0.96      0.96     17718
#
# The test accuracy score is:  0.958911841065583

# %%
X=df.iloc[:,8:11]
corr=X.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()


Y=df['activity']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

nb=GaussianNB()
nb.fit(X_train,Y_train)
Y_pred=nb.predict(X_test)
Y_pred_train=nb.predict(X_train)

print("The test classification report is: \n",classification_report(Y_pred,Y_test))
from sklearn.metrics import accuracy_score
print("The test accuracy score is: ",accuracy_score(Y_pred,Y_test))
# Out:
# The test classification report is:
#                precision    recall  f1-score   support
#
#            0       0.75      0.63      0.68     10579
#            1       0.56      0.69      0.61      7139
#
#     accuracy                           0.65     17718
#    macro avg       0.65      0.66      0.65     17718
# weighted avg       0.67      0.65      0.66     17718
#
# The test accuracy score is:  0.653459758437747
